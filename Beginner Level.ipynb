# %% [markdown]
# ![youngdev.png](youngdev.png)

# %% [markdown]
# # BEGINNER LEVEL

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.select_dtypes(include=['object', 'category']).nunique()
# Out:
# sex       2
# smoker    2
# region    4
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import  warnings

warnings.filterwarnings("ignore")

# %%
df.hist(figsize=(12, 10))
plt.show()

# %%
cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

fig, axes = plt.subplots(nrows=1, ncols=len(cat_cols), figsize=(12, 5))

for i, col in enumerate(cat_cols):
    sns.countplot(x=col, data=df, ax=axes[i])

plt.tight_layout()
plt.title("Frequency Categorical Variable.")
plt.show()

# %%
plt.figure(figsize=(10, 6)) 

plt.scatter(df["age"], df["charges"] , color='blue', alpha=0.7)  # Plot the scatter points
plt.title("Relationship between Age and Charges")
plt.xlabel('Age')  
plt.ylabel('Charges') 

plt.grid(True) 
plt.show()

# %%
plt.figure(figsize=(10, 6))


sns.scatterplot(x=df["age"] ,y=df["bmi"], color='red', alpha=0.7)

plt.title('Relationship between Age and Bmi')
plt.xlabel("Age")
plt.ylabel('Bmi')  

plt.grid(True)
plt.show()

# %%
df.hist("charges")
# Out:
# array([[<Axes: title={'center': 'charges'}>]], dtype=object)

# %%
df.boxplot(column= ["charges"], by = "sex")
# Out:
# <Axes: title={'center': 'charges'}, xlabel='sex'>

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)

sns.distplot(df["charges"])
plt.title("Charges PDF")

plt.subplot(122)

stats.probplot(df["charges"], dist="norm", plot = plt)
plt.title("Charges PDF")

plt.show()

# %%
df["log_charges"] = np.log2(df["charges"])

# %%
df.hist("log_charges")
plt.show()

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)

sns.distplot(df["log_charges"])
plt.title("Log_Charges PDF")

plt.subplot(122)

stats.probplot(df["log_charges"], dist="norm", plot = plt)
plt.title("Log_Charges QQ Plot")

plt.show()

# %%
df.boxplot(column= ["log_charges"], by = "sex")
# Out:
# <Axes: title={'center': 'log_charges'}, xlabel='sex'>

# %%
grouped_data = df.groupby(['sex',"smoker","region"])

mean_values = grouped_data['charges'].mean()


median_values = grouped_data['charges'].median()

std_deviation_values =  grouped_data['charges'].std()

# %%
print("Mean values:")
print(mean_values)

print("\nMedian values:")
print(median_values)

print("\nStandard Deviation values:")
print(std_deviation_values)
# Out:
# Mean values:
# sex     smoker  region
# female  no      northeast     9640.426984
#                 northwest     8786.998679
#                 southeast     8440.205552
#                 southwest     8234.091260
#         yes     northeast    28032.046398
#                 northwest    29670.824946
#                 southeast    33034.820716
#                 southwest    31687.988430
# male    no      northeast     8664.042222
#                 northwest     8320.689321
#                 southeast     7609.003587
#                 southwest     7778.905534
#         yes     northeast    30926.252583
#                 northwest    30713.181419
#                 southeast    36029.839367
#                 southwest    32598.862854
# Name: charges, dtype: float64
#
# Median values:
# sex     smoker  region
# female  no      northeast     8681.137100
#                 northwest     7731.857850
#                 southeast     7046.722200
#                 southwest     7348.142000
# ...

# %%
happiness2015 = pd.read_csv("wh_2015.csv")
happiness2016 = pd.read_csv("wh_2016.csv")
happiness2017 = pd.read_csv("wh_2017.csv")

# %%
shape_2015 = happiness2015.shape
shape_2016 = happiness2016.shape
shape_2017 = happiness2017.shape

# %%
shape_2015, shape_2016, shape_2017
# Out:
# ((164, 13), (164, 14), (164, 13))

# %%
missing = happiness2015['Happiness Score'].isnull()
missing_2015 = happiness2015[missing]

happiness2015.isnull().sum()
# Out:
# Country                          0
# Region                           6
# Happiness Rank                   6
# Happiness Score                  6
# Standard Error                   6
# Economy (GDP per Capita)         6
# Family                           6
# Health (Life Expectancy)         6
# Freedom                          6
# Trust (Government Corruption)    6
# Generosity                       6
# Dystopia Residual                6
# Year                             0
# dtype: int64

# %%
missing = happiness2015['Happiness Score'].isnull()
missing_2015 = happiness2015[missing]

happiness2015.isnull().sum()
# Out:
# Country                          0
# Region                           6
# Happiness Rank                   6
# Happiness Score                  6
# Standard Error                   6
# Economy (GDP per Capita)         6
# Family                           6
# Health (Life Expectancy)         6
# Freedom                          6
# Trust (Government Corruption)    6
# Generosity                       6
# Dystopia Residual                6
# Year                             0
# dtype: int64

# %%
missing_2016 = happiness2016.isnull().sum()
missing_2017 = happiness2017.isnull().sum()

# %%
missing_2016
# Out:
# Country                          0
# Region                           7
# Happiness Rank                   7
# Happiness Score                  7
# Lower Confidence Interval        7
# Upper Confidence Interval        7
# Economy (GDP per Capita)         7
# Family                           7
# Health (Life Expectancy)         7
# Freedom                          7
# Trust (Government Corruption)    7
# Generosity                       7
# Dystopia Residual                7
# Year                             0
# dtype: int64

# %%
missing_2017
# Out:
# Country                          0
# Happiness.Rank                   9
# Happiness.Score                  9
# Whisker.high                     9
# Whisker.low                      9
# Economy..GDP.per.Capita.         9
# Family                           9
# Health..Life.Expectancy.         9
# Freedom                          9
# Generosity                       9
# Trust..Government.Corruption.    9
# Dystopia.Residual                9
# Year                             0
# dtype: int64

# %%
combined = pd.concat([happiness2015, happiness2016, happiness2017], ignore_index=True)
combined
# Out:
#                Country          Region  Happiness Rank  Happiness Score  \
# 0          Switzerland  Western Europe             1.0            7.587
# 1              Iceland  Western Europe             2.0            7.561
# 2              Denmark  Western Europe             3.0            7.527
# 3               Norway  Western Europe             4.0            7.522
# 4               Canada   North America             5.0            7.427
# ..                 ...             ...             ...              ...
# 487        Puerto Rico             NaN             NaN              NaN
# 488  Somaliland Region             NaN             NaN              NaN
# 489  Somaliland region             NaN             NaN              NaN
# 490           Suriname             NaN             NaN              NaN
# 491          Swaziland             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
print(combined.isnull().sum())
# Out:
# Country                            0
# Region                           177
# Happiness Rank                   177
# Happiness Score                  177
# Standard Error                   334
# Economy (GDP per Capita)         177
# Family                            22
# Health (Life Expectancy)         177
# Freedom                           22
# Trust (Government Corruption)    177
# Generosity                        22
# Dystopia Residual                177
# Year                               0
# Lower Confidence Interval        335
# Upper Confidence Interval        335
# Happiness.Rank                   337
# Happiness.Score                  337
# Whisker.high                     337
# Whisker.low                      337
# Economy..GDP.per.Capita.         337
# Health..Life.Expectancy.         337
# Trust..Government.Corruption.    337
# Dystopia.Residual                337
# dtype: int64

# %%
happiness2017.columns = happiness2017.columns.str.replace('.', ' ').str.replace('\s+', ' ').str.strip().str.upper()
happiness2015.columns = happiness2015.columns.str.replace('(', '').str.replace(')', '').str.strip().str.upper()
happiness2016.columns = happiness2016.columns.str.replace('(', '').str.replace(')', '').str.strip().str.upper()

# %%
combined = pd.concat([happiness2015, happiness2016, happiness2017], ignore_index=True)
missing = combined.isnull().sum()

# %%
combined.shape
# Out:
# (492, 17)

# %%
combined.head()
# Out:
#        COUNTRY          REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    STANDARD ERROR  ECONOMY GDP PER CAPITA   FAMILY  HEALTH LIFE EXPECTANCY  \
# 0         0.03411                 1.39651  1.34951                 0.94143
# 1         0.04884                 1.30232  1.40223                 0.94784
# 2         0.03328                 1.32548  1.36058                 0.87464
# 3         0.03880                 1.45900  1.33095                 0.88521
# 4         0.03553                 1.32629  1.32261                 0.90563
#
#    FREEDOM  TRUST GOVERNMENT CORRUPTION  GENEROSITY  DYSTOPIA RESIDUAL  YEAR  \
# ...

# %%
missing
# Out:
# COUNTRY                          0
# REGION                         177
# HAPPINESS RANK                  22
# HAPPINESS SCORE                 22
# STANDARD ERROR                 334
# ECONOMY GDP PER CAPITA          22
# FAMILY                          22
# HEALTH LIFE EXPECTANCY          22
# FREEDOM                         22
# TRUST GOVERNMENT CORRUPTION     22
# GENEROSITY                      22
# DYSTOPIA RESIDUAL               22
# YEAR                             0
# LOWER CONFIDENCE INTERVAL      335
# UPPER CONFIDENCE INTERVAL      335
# WHISKER HIGH                   337
# WHISKER LOW                    337
# dtype: int64

# %%
combined.tail()
# Out:
#                COUNTRY REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# 487        Puerto Rico    NaN             NaN              NaN
# 488  Somaliland Region    NaN             NaN              NaN
# 489  Somaliland region    NaN             NaN              NaN
# 490           Suriname    NaN             NaN              NaN
# 491          Swaziland    NaN             NaN              NaN
#
#      STANDARD ERROR  ECONOMY GDP PER CAPITA  FAMILY  HEALTH LIFE EXPECTANCY  \
# 487             NaN                     NaN     NaN                     NaN
# 488             NaN                     NaN     NaN                     NaN
# 489             NaN                     NaN     NaN                     NaN
# 490             NaN                     NaN     NaN                     NaN
# 491             NaN                     NaN     NaN                     NaN
#
#      FREEDOM  TRUST GOVERNMENT CORRUPTION  GENEROSITY  DYSTOPIA RESIDUAL  \
# ...

# %%
combined_updated = combined.set_index('YEAR')
sns.heatmap(combined_updated.isnull(), cbar=False)
plt.show()

# %%
regions_2017 = combined[combined['YEAR']==2017]['REGION']
missing = regions_2017.isnull().sum()

# %%
happiness2015["COUNTRY"].isin(happiness2016["COUNTRY"]).sum()
# Out:
# 164

# %%
regions = pd.read_csv("region.csv")
regions
# Out:
#                  COUNTRY              REGION
# 0            Switzerland      Western Europe
# 1                Iceland      Western Europe
# 2                Denmark      Western Europe
# 3                 Norway      Western Europe
# 4                 Canada       North America
# ..                   ...                 ...
# 159    Somaliland Region  Sub-Saharan Africa
# 160              Namibia  Sub-Saharan Africa
# 161          South Sudan  Sub-Saharan Africa
# 162     Congo (Kinshasa)      Central Africa
# 163  Congo (Brazzaville)      Central Africa
#
# [164 rows x 2 columns]

# %%
combined = pd.merge(left=combined, right=regions, on='COUNTRY', how='left')
combined.columns
# Out:
# Index(['COUNTRY', 'REGION_x', 'HAPPINESS RANK', 'HAPPINESS SCORE',
#        'STANDARD ERROR', 'ECONOMY GDP PER CAPITA', 'FAMILY',
#        'HEALTH LIFE EXPECTANCY', 'FREEDOM', 'TRUST GOVERNMENT CORRUPTION',
#        'GENEROSITY', 'DYSTOPIA RESIDUAL', 'YEAR', 'LOWER CONFIDENCE INTERVAL',
#        'UPPER CONFIDENCE INTERVAL', 'WHISKER HIGH', 'WHISKER LOW', 'REGION_y'],
#       dtype='object')

# %%
combined[["REGION_x","REGION_y"]]
# Out:
#            REGION_x                     REGION_y
# 0    Western Europe               Western Europe
# 1    Western Europe               Western Europe
# 2    Western Europe               Western Europe
# 3    Western Europe               Western Europe
# 4     North America                North America
# ..              ...                          ...
# 487             NaN  Latin America and Caribbean
# 488             NaN           Sub-Saharan Africa
# 489             NaN           Sub-Saharan Africa
# 490             NaN  Latin America and Caribbean
# 491             NaN           Sub-Saharan Africa
#
# [492 rows x 2 columns]

# %%
missing = combined.isnull().sum()
missing
# Out:
# COUNTRY                          0
# REGION_x                       177
# HAPPINESS RANK                  22
# HAPPINESS SCORE                 22
# STANDARD ERROR                 334
# ECONOMY GDP PER CAPITA          22
# FAMILY                          22
# HEALTH LIFE EXPECTANCY          22
# FREEDOM                         22
# TRUST GOVERNMENT CORRUPTION     22
# GENEROSITY                      22
# DYSTOPIA RESIDUAL               22
# YEAR                             0
# LOWER CONFIDENCE INTERVAL      335
# UPPER CONFIDENCE INTERVAL      335
# WHISKER HIGH                   337
# WHISKER LOW                    337
# REGION_y                         0
# dtype: int64

# %%
combined = combined.drop('REGION_x', axis = 1)
missing = combined.isnull().sum()
missing
# Out:
# COUNTRY                          0
# HAPPINESS RANK                  22
# HAPPINESS SCORE                 22
# STANDARD ERROR                 334
# ECONOMY GDP PER CAPITA          22
# FAMILY                          22
# HEALTH LIFE EXPECTANCY          22
# FREEDOM                         22
# TRUST GOVERNMENT CORRUPTION     22
# GENEROSITY                      22
# DYSTOPIA RESIDUAL               22
# YEAR                             0
# LOWER CONFIDENCE INTERVAL      335
# UPPER CONFIDENCE INTERVAL      335
# WHISKER HIGH                   337
# WHISKER LOW                    337
# REGION_y                         0
# dtype: int64

# %%
combined.rename({"REGION_y":"REGION"}, axis = 1, inplace = True)

# %%
regions_columns = combined.iloc[:,-1]
exclude_regions_col = combined.iloc[:, :-1]


combined = pd.concat([regions_columns, exclude_regions_col], axis = 1)

# %%
regions_columns = combined.pop("REGION")

# %%
print(combined.columns)
regions_columns.head()
# Out:
# Index(['COUNTRY', 'HAPPINESS RANK', 'HAPPINESS SCORE', 'STANDARD ERROR',
#        'ECONOMY GDP PER CAPITA', 'FAMILY', 'HEALTH LIFE EXPECTANCY', 'FREEDOM',
#        'TRUST GOVERNMENT CORRUPTION', 'GENEROSITY', 'DYSTOPIA RESIDUAL',
#        'YEAR', 'LOWER CONFIDENCE INTERVAL', 'UPPER CONFIDENCE INTERVAL',
#        'WHISKER HIGH', 'WHISKER LOW'],
#       dtype='object')
# 0    Western Europe
# 1    Western Europe
# 2    Western Europe
# 3    Western Europe
# 4     North America
# Name: REGION, dtype: object

# %%
combined.insert(1, regions_columns.name, regions_columns)

combined.head()
# Out:
#        COUNTRY          REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    STANDARD ERROR  ECONOMY GDP PER CAPITA   FAMILY  HEALTH LIFE EXPECTANCY  \
# 0         0.03411                 1.39651  1.34951                 0.94143
# 1         0.04884                 1.30232  1.40223                 0.94784
# 2         0.03328                 1.32548  1.36058                 0.87464
# 3         0.03880                 1.45900  1.33095                 0.88521
# 4         0.03553                 1.32629  1.32261                 0.90563
#
#    FREEDOM  TRUST GOVERNMENT CORRUPTION  GENEROSITY  DYSTOPIA RESIDUAL  YEAR  \
# ...

# %%
dups = combined.duplicated(['COUNTRY', 'YEAR'])
combined[dups]
# Out:
# Empty DataFrame
# Columns: [COUNTRY, REGION, HAPPINESS RANK, HAPPINESS SCORE, STANDARD ERROR, ECONOMY GDP PER CAPITA, FAMILY, HEALTH LIFE EXPECTANCY, FREEDOM, TRUST GOVERNMENT CORRUPTION, GENEROSITY, DYSTOPIA RESIDUAL, YEAR, LOWER CONFIDENCE INTERVAL, UPPER CONFIDENCE INTERVAL, WHISKER HIGH, WHISKER LOW]
# Index: []

# %%
combined['COUNTRY'] = combined['COUNTRY'].str.upper()
dups = combined.duplicated(['COUNTRY', 'YEAR'])
combined_dups = combined[dups]

# %%
combined_dups
# Out:
#                COUNTRY              REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# 162  SOMALILAND REGION  Sub-Saharan Africa             NaN              NaN
# 326  SOMALILAND REGION  Sub-Saharan Africa             NaN              NaN
# 489  SOMALILAND REGION  Sub-Saharan Africa             NaN              NaN
#
#      STANDARD ERROR  ECONOMY GDP PER CAPITA  FAMILY  HEALTH LIFE EXPECTANCY  \
# 162             NaN                     NaN     NaN                     NaN
# 326             NaN                     NaN     NaN                     NaN
# 489             NaN                     NaN     NaN                     NaN
#
#      FREEDOM  TRUST GOVERNMENT CORRUPTION  GENEROSITY  DYSTOPIA RESIDUAL  \
# 162      NaN                          NaN         NaN                NaN
# 326      NaN                          NaN         NaN                NaN
# 489      NaN                          NaN         NaN                NaN
#
# ...

# %%
combined = combined.drop_duplicates(['COUNTRY', 'YEAR'])

# %%
combined.duplicated(['COUNTRY', 'YEAR']).sum()
# Out:
# 0

# %%
combined.isnull().sum()
# Out:
# COUNTRY                          0
# REGION                           0
# HAPPINESS RANK                  19
# HAPPINESS SCORE                 19
# STANDARD ERROR                 331
# ECONOMY GDP PER CAPITA          19
# FAMILY                          19
# HEALTH LIFE EXPECTANCY          19
# FREEDOM                         19
# TRUST GOVERNMENT CORRUPTION     19
# GENEROSITY                      19
# DYSTOPIA RESIDUAL               19
# YEAR                             0
# LOWER CONFIDENCE INTERVAL      332
# UPPER CONFIDENCE INTERVAL      332
# WHISKER HIGH                   334
# WHISKER LOW                    334
# dtype: int64

# %%
combined.notnull().sum().sort_values()
# Out:
# WHISKER LOW                    155
# WHISKER HIGH                   155
# UPPER CONFIDENCE INTERVAL      157
# LOWER CONFIDENCE INTERVAL      157
# STANDARD ERROR                 158
# DYSTOPIA RESIDUAL              470
# GENEROSITY                     470
# TRUST GOVERNMENT CORRUPTION    470
# FREEDOM                        470
# FAMILY                         470
# ECONOMY GDP PER CAPITA         470
# HAPPINESS SCORE                470
# HAPPINESS RANK                 470
# HEALTH LIFE EXPECTANCY         470
# YEAR                           489
# REGION                         489
# COUNTRY                        489
# dtype: int64

# %%
combined.dropna(thresh= 159, axis=1).head(2)
# Out:
#        COUNTRY          REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# 0  SWITZERLAND  Western Europe             1.0            7.587
# 1      ICELAND  Western Europe             2.0            7.561
#
#    ECONOMY GDP PER CAPITA   FAMILY  HEALTH LIFE EXPECTANCY  FREEDOM  \
# 0                 1.39651  1.34951                 0.94143  0.66557
# 1                 1.30232  1.40223                 0.94784  0.62877
#
#    TRUST GOVERNMENT CORRUPTION  GENEROSITY  DYSTOPIA RESIDUAL  YEAR
# 0                      0.41978     0.29678            2.51738  2015
# 1                      0.14145     0.43630            2.70201  2015

# %%
combined = combined.dropna(thresh=159, axis=1)
missing = combined.isnull().sum()

# %%
missing
# Out:
# COUNTRY                         0
# REGION                          0
# HAPPINESS RANK                 19
# HAPPINESS SCORE                19
# ECONOMY GDP PER CAPITA         19
# FAMILY                         19
# HEALTH LIFE EXPECTANCY         19
# FREEDOM                        19
# TRUST GOVERNMENT CORRUPTION    19
# GENEROSITY                     19
# DYSTOPIA RESIDUAL              19
# YEAR                            0
# dtype: int64

# %%
combined.set_index('REGION').sort_values(['REGION', 'HAPPINESS SCORE']).head()
# Out:
#                                COUNTRY  HAPPINESS RANK  HAPPINESS SCORE  \
# REGION
# Australia and New Zealand    AUSTRALIA            10.0            7.284
# Australia and New Zealand    AUSTRALIA            10.0            7.284
# Australia and New Zealand  NEW ZEALAND             9.0            7.286
# Australia and New Zealand    AUSTRALIA             9.0            7.313
# Australia and New Zealand  NEW ZEALAND             8.0            7.314
#
#                            ECONOMY GDP PER CAPITA    FAMILY  \
# REGION
# Australia and New Zealand                1.484415  1.510042
# Australia and New Zealand                1.333580  1.309230
# Australia and New Zealand                1.250180  1.319670
# Australia and New Zealand                1.444430  1.104760
# Australia and New Zealand                1.405706  1.548195
#
#                            HEALTH LIFE EXPECTANCY   FREEDOM  \
# REGION
# Australia and New Zealand                0.843887  0.601607
# ...

# %%
sorted_combined = combined.set_index('REGION').sort_values(['REGION', 'HAPPINESS SCORE'])
sns.heatmap(sorted_combined.isnull(), cbar=False)
plt.show()

# %%
combined.isnull().sum()
# Out:
# COUNTRY                         0
# REGION                          0
# HAPPINESS RANK                 19
# HAPPINESS SCORE                19
# ECONOMY GDP PER CAPITA         19
# FAMILY                         19
# HEALTH LIFE EXPECTANCY         19
# FREEDOM                        19
# TRUST GOVERNMENT CORRUPTION    19
# GENEROSITY                     19
# DYSTOPIA RESIDUAL              19
# YEAR                            0
# dtype: int64

# %%
combined.describe(include='all')
# Out:
#             COUNTRY              REGION  HAPPINESS RANK  HAPPINESS SCORE  \
# count           489                 489      470.000000       470.000000
# unique          163                  11             NaN              NaN
# top     SWITZERLAND  Sub-Saharan Africa             NaN              NaN
# freq              3                 123             NaN              NaN
# mean            NaN                 NaN       78.829787         5.370728
# std             NaN                 NaN       45.281408         1.136998
# min             NaN                 NaN        1.000000         2.693000
# 25%             NaN                 NaN       40.000000         4.509000
# 50%             NaN                 NaN       79.000000         5.282500
# 75%             NaN                 NaN      118.000000         6.233750
# max             NaN                 NaN      158.000000         7.587000
#
#         ECONOMY GDP PER CAPITA      FAMILY  HEALTH LIFE EXPECTANCY  \
# ...

# %%
combined.shape
# Out:
# (489, 12)

# %%
def fill_null_with_mean(DataFrame):
    for column in DataFrame.columns:
        if DataFrame[column].dtype != 'object':
            mean = DataFrame[column].mean()
            DataFrame[column].fillna(mean, inplace = True)
    return DataFrame

# %%
df = pd.DataFrame(combined)

# %%
filled_df = fill_null_with_mean(df)
print(filled_df)
# Out:
#                COUNTRY                           REGION  HAPPINESS RANK  \
# 0          SWITZERLAND                   Western Europe        1.000000
# 1              ICELAND                   Western Europe        2.000000
# 2              DENMARK                   Western Europe        3.000000
# 3               NORWAY                   Western Europe        4.000000
# 4               CANADA                    North America        5.000000
# ..                 ...                              ...             ...
# 486               OMAN  Middle East and Northern Africa       78.829787
# 487        PUERTO RICO      Latin America and Caribbean       78.829787
# 488  SOMALILAND REGION               Sub-Saharan Africa       78.829787
# 490           SURINAME      Latin America and Caribbean       78.829787
# 491          SWAZILAND               Sub-Saharan Africa       78.829787
#
#      HAPPINESS SCORE  ECONOMY GDP PER CAPITA    FAMILY  \
# ...

# %%
combined.isnull().sum()
# Out:
# COUNTRY                        0
# REGION                         0
# HAPPINESS RANK                 0
# HAPPINESS SCORE                0
# ECONOMY GDP PER CAPITA         0
# FAMILY                         0
# HEALTH LIFE EXPECTANCY         0
# FREEDOM                        0
# TRUST GOVERNMENT CORRUPTION    0
# GENEROSITY                     0
# DYSTOPIA RESIDUAL              0
# YEAR                           0
# dtype: int64

# %%
combined = combined.set_index('YEAR')
sns.heatmap(combined.isnull(), cbar=False)
plt.show()
